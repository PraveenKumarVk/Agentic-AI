# %% [markdown]
# # File QA RAG Chatbot App with ChatGPT, LangChain and Streamlit
#
# Here we will implement an advanced RAG System with ChatGPT, LangChain and Streamlit to build a File QA UI-based chatbot with the following features:
#
# - PDF Document Upload and Indexing
# - RAG System for query analysis and response
# - Result streaming capabilities (Real-time output)
# - Show document sources of the answer from RAG system

# %% [markdown]
# ## Install App and LLM dependencies

# %%
# !pip install langchain
# !pip install langchain-openai
# !pip install langchain-community
# !pip install streamlit
# !pip install PyMuPDF
# !pip install chromadb
# !pip install pyngrok
# !pip install langchain-huggingface
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (0.1.130)
# Requirement already satisfied: numpy<2,>=1 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain) (2.1)
# Requirement already satisfied: langchain-openai in /opt/anaconda3/lib/python3.11/site-packages (0.2.1)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-openai) (0.3.8)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-openai) (1.51.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (0.1.130)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.5.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.65.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.4)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-openai) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.7)
# Requirement already satisfied: langchain-community in /opt/anaconda3/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.3.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.3.8)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.1.130)
# Requirement already satisfied: numpy<2,>=1 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.1->langchain-community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.1->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.11/site-packages (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (7.0.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (1.26.4)
# Collecting packaging<24,>=16.8 (from streamlit)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=6.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (2.1)
# Requirement already satisfied: validators<1,>=0.2 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: decorator>=3.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Installing collected packages: packaging
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires jedi<0.19.0,>=0.17.2, but you have jedi 0.19.1 which is incompatible.
# Successfully installed packaging-23.2
# Requirement already satisfied: PyMuPDF in /opt/anaconda3/lib/python3.11/site-packages (1.24.0)
# Requirement already satisfied: PyMuPDFb==1.24.0 in /opt/anaconda3/lib/python3.11/site-packages (from PyMuPDF) (1.24.0)
# Requirement already satisfied: chromadb in /opt/anaconda3/lib/python3.11/site-packages (0.5.3)
# Requirement already satisfied: build>=1.0.3 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (0.112.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (1.16.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (6.4.4)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in /opt/anaconda3/lib/python3.11/site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: packaging>=19.1 in /opt/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /opt/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /opt/anaconda3/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.38.2)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in /opt/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: coloredlogs in /opt/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.5)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (75.2.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/anaconda3/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.24.6)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (13.3.5)
# Requirement already satisfied: httptools>=0.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (13.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/anaconda3/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: pyngrok in /opt/anaconda3/lib/python3.11/site-packages (7.1.5)
# Requirement already satisfied: PyYAML>=5.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyngrok) (6.0.1)
# Collecting langchain-huggingface
#   Using cached langchain_huggingface-0.1.2-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-huggingface) (0.24.6)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain-huggingface)
#   Using cached langchain_core-0.3.31-py3-none-any.whl.metadata (6.3 kB)
# Collecting sentence-transformers>=2.6.0 (from langchain-huggingface)
#   Using cached sentence_transformers-3.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tokenizers>=0.19.1 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-huggingface) (0.20.0)
# Collecting transformers>=4.39.0 (from langchain-huggingface)
#   Using cached transformers-4.48.1-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (6.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.1.130)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (8.5.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.2.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.2.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.11.4)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (10.2.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.39.0->langchain-huggingface) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.39.0->langchain-huggingface) (2023.10.3)
# Collecting tokenizers>=0.19.1 (from langchain-huggingface)
#   Using cached tokenizers-0.21.0-cp39-abi3-macosx_10_12_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2024.8.30)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (2.2.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.0.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Using cached langchain_huggingface-0.1.2-py3-none-any.whl (21 kB)
# Using cached langchain_core-0.3.31-py3-none-any.whl (412 kB)
# Using cached sentence_transformers-3.4.0-py3-none-any.whl (275 kB)
# Using cached transformers-4.48.1-py3-none-any.whl (9.7 MB)
# Using cached tokenizers-0.21.0-cp39-abi3-macosx_10_12_x86_64.whl (2.6 MB)
# Installing collected packages: tokenizers, transformers, langchain-core, sentence-transformers, langchain-huggingface
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.0
#     Uninstalling tokenizers-0.20.0:
#       Successfully uninstalled tokenizers-0.20.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.8
#     Uninstalling langchain-core-0.3.8:
#       Successfully uninstalled langchain-core-0.3.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-chroma 0.1.3 requires langchain-core<0.3,>=0.1.40, but you have langchain-core 0.3.31 which is incompatible.
# Successfully installed langchain-core-0.3.31 langchain-huggingface-0.1.2 sentence-transformers-3.4.0 tokenizers-0.21.0 transformers-4.48.1

# %% [markdown]
# ## Load OpenAI API Credentials
#
# Here we load it from a file so we don't explore the credentials on the internet by mistake

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
import yaml

with open('chatgpt-api-credentials.yml', 'r') as file:
    api_creds = yaml.safe_load(file)

# %%
api_creds.keys()
# Out:
# dict_keys(['OPENAI-API-KEY'])

# %%
import os

os.environ['OPENAI_API_KEY'] = api_creds['OPENAI-API-KEY']

# %% [markdown]
# ## Write the app code here and store it in a py file

# %%
# %%writefile app.py

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.chat_message_histories import StreamlitChatMessageHistory
from langchain_core.callbacks.base import BaseCallbackHandler
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores.chroma import Chroma
from langchain_huggingface import HuggingFacePipeline
from operator import itemgetter
import streamlit as st
import tempfile
import os
import pandas as pd

# Customize initial app landing page
st.set_page_config(page_title="File QA Chatbot", page_icon="🤖")
st.title("Welcome to File QA RAG Chatbot 🤖")

@st.cache_resource(ttl="1h")
# Takes uploaded PDFs, creates document chunks, computes embeddings
# Stores document chunks and embeddings in a Vector DB
# Returns a retriever which can look up the Vector DB
# to return documents based on user input
# Stores this in the cache
def configure_retriever(uploaded_files):
  # Read documents
  docs = []
  temp_dir = tempfile.TemporaryDirectory()
  for file in uploaded_files:
    temp_filepath = os.path.join(temp_dir.name, file.name)
    with open(temp_filepath, "wb") as f:
      f.write(file.getvalue())
    loader = PyMuPDFLoader(temp_filepath)
    docs.extend(loader.load())

  # Split into documents chunks
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500,
                                                 chunk_overlap=200)
  doc_chunks = text_splitter.split_documents(docs)

  # Create document embeddings and store in Vector DB
  embeddings_model = OpenAIEmbeddings()
  vectordb = Chroma.from_documents(doc_chunks, embeddings_model)

  # Define retriever object
  retriever = vectordb.as_retriever()
  return retriever

# Manages live updates to a Streamlit app's display by appending new text tokens
# to an existing text stream and rendering the updated text in Markdown
class StreamHandler(BaseCallbackHandler):
  def __init__(self, container, initial_text=""):
    self.container = container
    self.text = initial_text

  def on_llm_new_token(self, token: str, **kwargs) -> None:
    self.text += token
    self.container.markdown(self.text)

# Creates UI element to accept PDF uploads
uploaded_files = st.sidebar.file_uploader(
  label="Upload PDF files", type=["pdf"],
  accept_multiple_files=True
)
if not uploaded_files:
  st.info("Please upload PDF documents to continue.")
  st.stop()

# Create retriever object based on uploaded PDFs
retriever = configure_retriever(uploaded_files)

# Load a connection to ChatGPT LLM
chatgpt = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.1,
                     streaming=True)

# Create a prompt template for QA RAG System
qa_template = """
              Use only the following pieces of context to answer the question at the end.
              If you don't know the answer, just say that you don't know,
              don't try to make up an answer. Keep the answer as concise as possible.

              {context}

              Question: {question}
              """
qa_prompt = ChatPromptTemplate.from_template(qa_template)

# This function formats retrieved documents before sending to LLM
def format_docs(docs):
  return "\n\n".join([d.page_content for d in docs])

# Create a QA RAG System Chain
qa_rag_chain = (
  {
    "context": itemgetter("question") # based on the user question get context docs
      |
    retriever
      |
    format_docs,
    "question": itemgetter("question") # user question
  }
    |
  qa_prompt # prompt with above user question and context
    |
  chatgpt # above prompt is sent to the LLM for response
)

# Store conversation history in Streamlit session state
streamlit_msg_history = StreamlitChatMessageHistory(key="langchain_messages")

# Shows the first message when app starts
if len(streamlit_msg_history.messages) == 0:
  streamlit_msg_history.add_ai_message("Please ask your question?")

# Render current messages from StreamlitChatMessageHistory
for msg in streamlit_msg_history.messages:
  st.chat_message(msg.type).write(msg.content)

# Callback handler which does some post-processing on the LLM response
# Used to post the top 3 document sources used by the LLM in RAG response
class PostMessageHandler(BaseCallbackHandler):
  def __init__(self, msg: st.write):
    BaseCallbackHandler.__init__(self)
    self.msg = msg
    self.sources = []

  def on_retriever_end(self, documents, *, run_id, parent_run_id, **kwargs):
    source_ids = []
    for d in documents: # retrieved documents from retriever based on user query
      metadata = {
        "source": d.metadata["source"],
        "page": d.metadata["page"],
        "content": d.page_content[:200]
      }
      idx = (metadata["source"], metadata["page"])
      if idx not in source_ids: # store unique source documents
        source_ids.append(idx)
        self.sources.append(metadata)

  def on_llm_end(self, response, *, run_id, parent_run_id, **kwargs):
    if len(self.sources):
      st.markdown("__Sources:__ "+"\n")
      st.dataframe(data=pd.DataFrame(self.sources[:3]),
                    width=1000) # Top 3 sources


# If user inputs a new prompt, display it and show the response
if user_prompt := st.chat_input():
  st.chat_message("human").write(user_prompt)
  # This is where response from the LLM is shown
  with st.chat_message("ai"):
    # Initializing an empty data stream
    stream_handler = StreamHandler(st.empty())
    # UI element to write RAG sources after LLM response
    sources_container = st.write("")
    pm_handler = PostMessageHandler(sources_container)
    config = {"callbacks": [stream_handler, pm_handler]}
    # Get LLM response
    response = qa_rag_chain.invoke({"question": user_prompt},
                                    config)
# Out:
# Overwriting app.py

# %% [markdown]
# ## Start the app

# %%
# !pip install --upgrade streamlit
# Out:
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.11/site-packages (1.30.0)
# Collecting streamlit
#   Using cached streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: altair<6,>=4.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<12,>=7.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Using cached streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
# Installing collected packages: streamlit
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.30.0
#     Uninstalling streamlit-1.30.0:
#       Successfully uninstalled streamlit-1.30.0
# Successfully installed streamlit-1.41.1

# %%
# !streamlit run app.py --server.port=8989 --server.headless true
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8989
#   Network URL: http://192.168.1.200:8989
#   External URL: http://76.36.23.136:8989
# t=2025-01-25T13:59:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:60003->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-25T13:59:37-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9cc31cf7f9c7 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T14:05:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:60364->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-25T14:05:28-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=be52e1325729 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T14:25:06-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:60558->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-25T14:25:20-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9587b2d06f87 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T14:57:09-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:60671->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-25T14:57:50-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=f229e8785a8e clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T14:57:50-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-25T14:58:22-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b667e6fe0c9a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T14:59:02-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4533ecb40194 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T14:59:02-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-25T14:59:31-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:60839->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-25T16:09:04-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:60850->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-25T16:09:13-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=209f9342df3f clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T16:09:18-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=83b213e67603 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T17:05:41-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:60874->[2600:1f16:d83:1200::6e74:0]:443: write: broken pipe"
# t=2025-01-25T17:05:55-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4dea13691274 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T17:06:54-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:62265->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-25T17:07:10-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=40e2a379c805 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T17:25:09-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:62320->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-25T17:25:28-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=cd68c46a8d2c clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T17:40:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:62356->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-25T17:40:34-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9598fed7e411 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T17:49:05-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:62652->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-25T17:49:26-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=a21bb17045eb clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T18:06:47-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:62902->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-25T18:07:04-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d535d3fcbb4a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T18:41:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63125->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-25T18:41:37-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=dd3913b1b8c0 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T19:12:29-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63357->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-25T19:12:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4913d342ec35 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T19:13:47-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63433->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-25T19:44:22-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63497->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-25T19:44:23-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=389fd31c5500 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T19:44:38-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2021cfe9fb67 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T20:11:31-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63522->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-25T20:12:15-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d72a6ea3a3c9 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T20:12:54-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=8987ac67778b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T20:12:54-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-25T20:43:37-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63628->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-25T20:44:17-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=a153793e58a4 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T20:44:17-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-25T20:44:52-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63684->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-25T20:45:01-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e7b4e0d3e5ef clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T20:45:06-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=1444119fa09a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T20:59:24-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63708->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-25T20:59:39-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=de01c2a500dc clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T21:52:28-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:63742->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-25T21:52:46-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=be0a6d7d3587 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T22:05:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:65316->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-25T22:05:29-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2822bb2a5562 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-25T22:20:34-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:8977:2a63:f86b:f28c]:65359->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-25T22:20:52-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=c27651545736 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T01:42:00-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2fc573c9b412 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T01:42:00-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-26T01:42:00-0500 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-01-26T01:42:01-0500 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-01-26T01:42:02-0500 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-01-26T01:42:04-0500 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-01-26T01:42:08-0500 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-01-26T02:43:03-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:51534->[2600:1f16:d83:1201::6e74:1]:443: write: broken pipe"
# t=2025-01-26T02:43:11-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=0b411bfa160e clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T03:14:16-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:52763->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T03:14:59-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e03ec1e6cf53 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T03:15:00-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T03:15:41-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9f291379a531 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T03:15:42-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T03:15:52-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=fe4f60511255 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T03:44:10-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:52876->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T03:44:20-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=c51ac7a98c37 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T03:44:55-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T03:45:37-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:52935->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-26T03:45:41-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=397ba6996d22 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T03:45:48-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=774c108db3b2 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T04:16:43-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:52952->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-26T04:17:26-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d4734ed10bdb clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T04:17:26-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:52982->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T04:18:09-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=c4bf3761859a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T04:18:09-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T04:18:19-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=79f8e43aa42d clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T04:18:53-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T04:19:33-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9d89400c51b3 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T04:19:34-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53039->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T04:45:16-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b42ef415c39f clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T04:45:16-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53055->[2600:1f16:d83:1200::6e74:0]:443: write: broken pipe"
# t=2025-01-26T04:45:27-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2c839ef7c53c clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T05:16:25-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53082->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T05:17:05-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53138->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T05:17:07-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=da857994adb5 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T05:17:47-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e5c65f62ee9e clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T05:17:47-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T05:17:58-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7b4bcc26e638 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T05:46:23-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53181->[2600:1f16:d83:1202::6e74:2]:443: write: broken pipe"
# t=2025-01-26T05:46:34-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4712fe0a7d99 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T05:47:16-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T05:47:27-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9bdc7f724a6b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T05:52:00-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53245->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T06:22:39-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=ad712009ed75 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T06:22:39-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53282->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T06:23:21-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=1ebff266ab7b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T06:23:22-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T06:24:04-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9ca2e0dd3260 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T06:24:04-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T06:24:46-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=fbc5ea24d037 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T06:24:47-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53340->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T06:25:27-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e826b4c170be clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T06:25:27-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53356->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T06:47:30-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=3a4995f09ea3 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T06:47:31-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53374->[2600:1f16:d83:1201::6e74:4]:443: write: broken pipe"
# t=2025-01-26T06:47:42-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=93aeae522112 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:18:36-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53399->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-26T07:18:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4e94f0b5d65b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:19:17-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53435->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-26T07:19:58-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9f536cd43a78 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:20:00-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T07:20:11-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=77d893281fda clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:21:04-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53476->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T07:21:13-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e1dadf45ddd1 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:48:38-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53505->[2600:1f16:d83:1200::6e74:0]:443: write: broken pipe"
# t=2025-01-26T07:49:19-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=52bc401c7c35 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:49:20-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53518->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-26T07:50:01-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b6e1147b8436 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:50:02-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T07:50:44-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7e8e59913655 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T07:50:45-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53562->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T07:50:55-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=1c3ec2030e18 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T08:49:45-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53584->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T09:50:52-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=84055108d369 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T09:50:52-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53615->[2600:1f16:d83:1200::6e74:3]:443: write: broken pipe"
# t=2025-01-26T09:51:01-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=f80f638b3757 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T10:51:58-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53645->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T10:52:07-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d37278a690f4 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T11:53:16-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=a03774138991 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T11:53:16-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-26T12:11:22-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53781->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T12:11:40-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=fc9323994827 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T12:35:28-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53922->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T12:35:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=972677cd98f6 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T12:52:13-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:54200->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T12:52:30-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=cb4becd9e116 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T13:08:29-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:54270->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-26T13:08:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=bf8fa26fcf7a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T14:32:49-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="write tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:54336->[2600:1f16:d83:1201::6e74:1]:443: write: broken pipe"
# t=2025-01-26T14:33:05-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=5a09b8b04793 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T14:53:47-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:56217->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T14:54:05-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e0092ecbde59 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T15:13:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:56391->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T15:13:35-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=00395e31ec83 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T15:34:00-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:56525->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-26T15:34:16-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2b69bbec0cd8 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T15:54:09-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:56651->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T15:54:30-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=906902adb5f0 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T16:13:06-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:56782->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T16:13:23-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=358c0a2c2f52 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T16:32:02-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:56913->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-26T16:32:23-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7a134354c711 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T16:55:05-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57036->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-26T16:55:21-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b4713e520f78 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T17:14:21-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57249->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T17:14:35-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=8a7bdcf561dc clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T17:35:36-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57395->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T17:35:52-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=3aac6ff296eb clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T17:54:40-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57527->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T17:54:54-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=17438b7a5cef clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T18:11:05-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57667->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T18:11:20-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d925ae7d204c clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T18:30:48-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57717->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-26T18:31:08-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=5eae25afbdde clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T18:50:29-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57851->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-26T18:50:47-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=90ef5544989a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T18:56:08-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57982->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T18:56:27-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=78050d47d5a0 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T19:14:50-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58125->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T19:15:12-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=6a04095740c7 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T19:34:28-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58245->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T19:34:42-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e4cb2f780ea1 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T19:53:08-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58385->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T19:53:22-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=db404901f869 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T20:12:22-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58524->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T20:12:37-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=ec0273a780bb clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T20:31:10-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58665->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-26T20:31:24-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e1d6e5fbd8bb clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T20:52:10-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58823->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-26T20:52:30-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=eb7a3f62ae94 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T20:57:10-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58959->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-26T20:57:31-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b6f791675331 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T21:17:38-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59087->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T21:17:59-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=fe80dc5fccde clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T21:31:46-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59215->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T21:32:04-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=cccca89931b6 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T21:33:02-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-26T21:33:27-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d68b06e6862a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T21:51:17-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59444->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-26T21:51:34-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=51f496115a76 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T21:58:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59483->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-26T21:58:28-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7f0ddf91b05d clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T22:14:30-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59681->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-26T22:14:47-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=1333431983c1 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T22:18:01-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59722->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-26T22:18:18-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=531f61e0ed14 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T22:39:31-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59785->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T22:39:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=965dced6a93f clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T22:59:14-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59919->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T22:59:30-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4bf2e3f5920b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T23:18:58-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60056->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-26T23:19:17-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=8d461684aba0 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T23:37:51-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60198->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-26T23:38:08-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=0847353f7b85 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-26T23:55:54-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60327->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-26T23:56:15-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b9e87c374dbf clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T00:00:16-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60385->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-27T00:00:31-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2393ceedd769 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T00:22:14-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60471->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-27T00:22:27-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=3b2d1f1e2496 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T00:39:23-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60613->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-27T00:39:44-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=8bb5bdfc6271 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T00:56:39-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60673->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-27T00:57:02-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=95b7a9110b05 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T01:01:18-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60763->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-27T01:01:32-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=bdbf22e00097 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T01:21:01-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60819->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-27T01:21:22-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=80504b9761fa clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T01:30:01-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60941->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-27T01:30:22-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2fdf13635e8a clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T02:01:20-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=5e88ab273849 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T02:01:20-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-27T02:32:40-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:61108->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-27T02:33:22-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=0fee8f72ada3 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T02:33:24-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-27T02:34:04-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=277cd16a6127 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T02:34:05-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-27T02:34:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=8c1374156bc9 clientid=c7ea17ee53530837f8be22609be138a6
# ...
# t=2025-01-27T15:21:06-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d513c15ac57d clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T15:43:25-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:52473->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-27T15:43:40-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=edb97bbf23ee clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T16:18:59-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53210->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-27T16:19:14-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=92f22f7311e1 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T16:38:37-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e9d194a4bcbc clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T16:38:37-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-27T17:34:27-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:53463->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-27T17:34:42-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=26d25944b601 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T17:46:26-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:54559->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-27T18:03:36-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:54771->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-27T18:03:38-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=21a8ca7043c1 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T18:03:49-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=60daeabc53ab clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T18:38:21-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:54788->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-27T18:38:28-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=5cec4ba36da5 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T18:43:20-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=55ef9e445bd0 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T18:43:20-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-27T19:21:27-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:55379->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-27T19:21:40-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=36ee7254e744 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T19:43:00-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:56641->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-27T19:43:15-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=243a47e3c142 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T19:46:33-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-27T19:46:34-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=0a0fbec41aba clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T20:41:58-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57130->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-27T20:42:13-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=efe6d961ffb6 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T20:59:22-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:57988->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-27T20:59:37-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b7300c2b62a1 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T21:22:04-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58044->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-27T21:22:19-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=12bbe55b2c26 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T21:40:22-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58314->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-27T21:40:37-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7c5f8a6bcca5 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T21:59:31-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58365->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-27T21:59:47-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e44d5f4dbde1 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T22:07:30-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58502->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-27T22:07:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=500a2f7598dc clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T22:27:15-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58693->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-27T22:27:30-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9ab62d35affd clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T23:08:27-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:58810->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2025-01-27T23:39:06-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b28a4e9ec51c clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T23:39:11-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59588->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-27T23:39:50-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=08c801a67633 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T23:40:24-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=886d14efc5f4 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T23:40:24-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-27T23:41:36-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=3071019ff366 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-27T23:41:36-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-28T00:09:39-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7513cdaf56e8 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T00:09:39-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-28T00:40:24-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59722->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-28T00:41:01-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=ebc5e63208de clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T00:41:08-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-28T00:41:35-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-28T00:41:37-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=118c4b6cc77b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T00:42:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=63d935f6627e clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T00:42:48-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b7f6efa6eaaf clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T00:42:48-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-28T00:43:31-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-28T00:43:58-0500 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to send authentication request: session closed"
# t=2025-01-28T00:44:00-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=9e323cbfa786 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T01:10:35-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59849->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2025-01-28T01:41:10-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59893->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-28T01:41:14-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=c3831af448d7 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T01:41:45-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-28T01:41:48-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=eabc22d89b04 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T01:41:59-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=6eec2463de13 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T01:42:39-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-28T01:42:45-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=8d1df3617ac3 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T02:10:45-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:59974->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2025-01-28T02:11:00-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4644d73855b5 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T02:42:10-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60013->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2025-01-28T02:42:24-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e4b090778e01 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T04:05:09-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:60180->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-28T04:05:21-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=41662090a214 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T04:06:14-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read EOF from remote peer"
# t=2025-01-28T04:06:19-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=29d1e41de1ba clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T04:27:36-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:63884->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-28T04:27:51-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=31768f09678b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T05:53:21-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:63921->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2025-01-28T05:54:00-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=a1435a4c7f1b clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T05:54:33-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=780fc8a9bd17 clientid=c7ea17ee53530837f8be22609be138a6
# t=2025-01-28T05:54:33-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="session closed"
# t=2025-01-28T06:27:45-0500 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=75ba8d3aa4cf err="read tcp [2603:6080:43f0:8850:c111:ab4b:75f1:cdb9]:51734->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2025-01-28T06:28:00-0500 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e2de55e1aa89 clientid=c7ea17ee53530837f8be22609be138a6

# %%
from pyngrok import ngrok
import yaml

# Terminate open tunnels if exist
ngrok.kill()

# Setting the authtoken
# Get your authtoken from `ngrok_credentials.yml` file
with open('ngrok-api-credentials.yml', 'r') as file:
    NGROK_AUTH_TOKEN = yaml.safe_load(file)
ngrok.set_auth_token(NGROK_AUTH_TOKEN['NGROK_API'])

# Open an HTTPs tunnel on port XXXX which you get from your `logs.txt` file
ngrok_tunnel = ngrok.connect(8989)
print("Streamlit App:", ngrok_tunnel.public_url)
# Out:
# Streamlit App: https://fc89-2603-6080-43f0-8850-8977-2a63-f86b-f28c.ngrok-free.app
# t=2025-01-25T13:44:28-0500 lvl=warn msg="failed to open private leg" id=c3bc02d1e95e privaddr=localhost:8989 err="dial tcp [::1]:8989: connect: connection refused"
# t=2025-01-25T13:44:29-0500 lvl=warn msg="failed to open private leg" id=4d8241bf3019 privaddr=localhost:8989 err="dial tcp [::1]:8989: connect: connection refused"

# %% [markdown]
# ## Remove running app processes

# %%
ngrok.kill()

# %%
# !ps -ef | grep streamlit
# Out:
# root        1110       1  1 05:29 ?        00:00:20 /usr/bin/python3 /usr/local/bin/streamlit run ap
# root        9062     306  0 06:02 ?        00:00:00 /bin/bash -c ps -ef | grep streamlit
# root        9064    9062  0 06:02 ?        00:00:00 grep streamlit

# %%
# !sudo kill -9 1110
